# %% [markdown]
# ## Convolutional Neural Networks: Dog Breed Identification
#
# ---
# The objective of this homework is to design, train and test several models for dog breed identification from images.
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. Lines starting with "`# ...`" are places where you need to write code.

# %% [markdown]
# ## Step 1: Detect Dogs
#
# The first we want to do is an algorithm for dog detection. We will implement such algorithm by using a pre-trained CNN network called [Inception](https://www.cv-foundation.org/openaccess/content_cvpr_2015/papers/Szegedy_Going_Deeper_With_2015_CVPR_paper.pdf). You don't need to train a model in this stage, but only use the pre-trained one.
#
# Inception is trained on [ImageNet](http://www.image-net.org/), a large and popular dataset used for image classification and other vision tasks. ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a). Of these categories, many represent dog classes, and we are going to exploit this fact to design our dog detection algorithm.
#
# You can find the dataset on a Google Drive share: https://drive.google.com/drive/u/0/folders/1gurKn1WCO_PdwfUVjd9WFaZrSZygeKoM

# %%
# Import Torch
import torch
# Setup device
dev = ("cuda" if torch.cuda.is_available() else "cpu")
print(dev)
# Out:
# cuda

# %%
# Imports
import torchvision.models as models

# Configre Inception model
# HINTS:
# - check the documentation: https://pytorch.org/docs/stable/torchvision/models.html
# - make sure you use the pretrained version
# ...
inception = models.inception_v3(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))

# %% [markdown]
# #### Pre-process the Data
#
# According to the documentation:
# - Inception requires 299$\times$299 input images.
# - Images need to be normalized using mean = [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225].

# %% [markdown]
# In order to use the Inception model, we need to prepare our images accordingly. We will use a dataset that automatically loads images as `PIL.Image` objects, so we can expect our input to be in that form.

# %%
import torchvision.transforms as T

# Define transform for Inception model
norm_mean = (0.485, 0.456, 0.406)
norm_std = (0.229, 0.224, 0.225)
normalize = T.Normalize(norm_mean, norm_std)

inception_transform = T.Compose([
    T.Resize([299, 299]),
    T.ToTensor(), 
    normalize])

# %% [markdown]
# First of all, let's check that our Inception network works. Let's pass some images as input to the model, and compute the predicted label. We have a dictionary that maps numeric labels so class names.

# %%
# ImageNet class map
class_names = {0: 'tench, Tinca tinca', 1: 'goldfish, Carassius auratus', 2: 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias', 3: 'tiger shark, Galeocerdo cuvieri', 4: 'hammerhead, hammerhead shark', 5: 'electric ray, crampfish, numbfish, torpedo', 6: 'stingray', 7: 'cock', 8: 'hen', 9: 'ostrich, Struthio camelus', 10: 'brambling, Fringilla montifringilla', 11: 'goldfinch, Carduelis carduelis', 12: 'house finch, linnet, Carpodacus mexicanus', 13: 'junco, snowbird', 14: 'indigo bunting, indigo finch, indigo bird, Passerina cyanea', 15: 'robin, American robin, Turdus migratorius', 16: 'bulbul', 17: 'jay', 18: 'magpie', 19: 'chickadee', 20: 'water ouzel, dipper', 21: 'kite', 22: 'bald eagle, American eagle, Haliaeetus leucocephalus', 23: 'vulture', 24: 'great grey owl, great gray owl, Strix nebulosa', 25: 'European fire salamander, Salamandra salamandra', 26: 'common newt, Triturus vulgaris', 27: 'eft', 28: 'spotted salamander, Ambystoma maculatum', 29: 'axolotl, mud puppy, Ambystoma mexicanum', 30: 'bullfrog, Rana catesbeiana', 31: 'tree frog, tree-frog', 32: 'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui', 33: 'loggerhead, loggerhead turtle, Caretta caretta', 34: 'leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea', 35: 'mud turtle', 36: 'terrapin', 37: 'box turtle, box tortoise', 38: 'banded gecko', 39: 'common iguana, iguana, Iguana iguana', 40: 'American chameleon, anole, Anolis carolinensis', 41: 'whiptail, whiptail lizard', 42: 'agama', 43: 'frilled lizard, Chlamydosaurus kingi', 44: 'alligator lizard', 45: 'Gila monster, Heloderma suspectum', 46: 'green lizard, Lacerta viridis', 47: 'African chameleon, Chamaeleo chamaeleon', 48: 'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis', 49: 'African crocodile, Nile crocodile, Crocodylus niloticus', 50: 'American alligator, Alligator mississipiensis', 51: 'triceratops', 52: 'thunder snake, worm snake, Carphophis amoenus', 53: 'ringneck snake, ring-necked snake, ring snake', 54: 'hognose snake, puff adder, sand viper', 55: 'green snake, grass snake', 56: 'king snake, kingsnake', 57: 'garter snake, grass snake', 58: 'water snake', 59: 'vine snake', 60: 'night snake, Hypsiglena torquata', 61: 'boa constrictor, Constrictor constrictor', 62: 'rock python, rock snake, Python sebae', 63: 'Indian cobra, Naja naja', 64: 'green mamba', 65: 'sea snake', 66: 'horned viper, cerastes, sand viper, horned asp, Cerastes cornutus', 67: 'diamondback, diamondback rattlesnake, Crotalus adamanteus', 68: 'sidewinder, horned rattlesnake, Crotalus cerastes', 69: 'trilobite', 70: 'harvestman, daddy longlegs, Phalangium opilio', 71: 'scorpion', 72: 'black and gold garden spider, Argiope aurantia', 73: 'barn spider, Araneus cavaticus', 74: 'garden spider, Aranea diademata', 75: 'black widow, Latrodectus mactans', 76: 'tarantula', 77: 'wolf spider, hunting spider', 78: 'tick', 79: 'centipede', 80: 'black grouse', 81: 'ptarmigan', 82: 'ruffed grouse, partridge, Bonasa umbellus', 83: 'prairie chicken, prairie grouse, prairie fowl', 84: 'peacock', 85: 'quail', 86: 'partridge', 87: 'African grey, African gray, Psittacus erithacus', 88: 'macaw', 89: 'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita', 90: 'lorikeet', 91: 'coucal', 92: 'bee eater', 93: 'hornbill', 94: 'hummingbird', 95: 'jacamar', 96: 'toucan', 97: 'drake', 98: 'red-breasted merganser, Mergus serrator', 99: 'goose', 100: 'black swan, Cygnus atratus', 101: 'tusker', 102: 'echidna, spiny anteater, anteater', 103: 'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus', 104: 'wallaby, brush kangaroo', 105: 'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus', 106: 'wombat', 107: 'jellyfish', 108: 'sea anemone, anemone', 109: 'brain coral', 110: 'flatworm, platyhelminth', 111: 'nematode, nematode worm, roundworm', 112: 'conch', 113: 'snail', 114: 'slug', 115: 'sea slug, nudibranch', 116: 'chiton, coat-of-mail shell, sea cradle, polyplacophore', 117: 'chambered nautilus, pearly nautilus, nautilus', 118: 'Dungeness crab, Cancer magister', 119: 'rock crab, Cancer irroratus', 120: 'fiddler crab', 121: 'king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica', 122: 'American lobster, Northern lobster, Maine lobster, Homarus americanus', 123: 'spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish', 124: 'crayfish, crawfish, crawdad, crawdaddy', 125: 'hermit crab', 126: 'isopod', 127: 'white stork, Ciconia ciconia', 128: 'black stork, Ciconia nigra', 129: 'spoonbill', 130: 'flamingo', 131: 'little blue heron, Egretta caerulea', 132: 'American egret, great white heron, Egretta albus', 133: 'bittern', 134: 'crane', 135: 'limpkin, Aramus pictus', 136: 'European gallinule, Porphyrio porphyrio', 137: 'American coot, marsh hen, mud hen, water hen, Fulica americana', 138: 'bustard', 139: 'ruddy turnstone, Arenaria interpres', 140: 'red-backed sandpiper, dunlin, Erolia alpina', 141: 'redshank, Tringa totanus', 142: 'dowitcher', 143: 'oystercatcher, oyster catcher', 144: 'pelican', 145: 'king penguin, Aptenodytes patagonica', 146: 'albatross, mollymawk', 147: 'grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus', 148: 'killer whale, killer, orca, grampus, sea wolf, Orcinus orca', 149: 'dugong, Dugong dugon', 150: 'sea lion', 151: 'Chihuahua', 152: 'Japanese spaniel', 153: 'Maltese dog, Maltese terrier, Maltese', 154: 'Pekinese, Pekingese, Peke', 155: 'Shih-Tzu', 156: 'Blenheim spaniel', 157: 'papillon', 158: 'toy terrier', 159: 'Rhodesian ridgeback', 160: 'Afghan hound, Afghan', 161: 'basset, basset hound', 162: 'beagle', 163: 'bloodhound, sleuthhound', 164: 'bluetick', 165: 'black-and-tan coonhound', 166: 'Walker hound, Walker foxhound', 167: 'English foxhound', 168: 'redbone', 169: 'borzoi, Russian wolfhound', 170: 'Irish wolfhound', 171: 'Italian greyhound', 172: 'whippet', 173: 'Ibizan hound, Ibizan Podenco', 174: 'Norwegian elkhound, elkhound', 175: 'otterhound, otter hound', 176: 'Saluki, gazelle hound', 177: 'Scottish deerhound, deerhound', 178: 'Weimaraner', 179: 'Staffordshire bullterrier, Staffordshire bull terrier', 180: 'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier', 181: 'Bedlington terrier', 182: 'Border terrier', 183: 'Kerry blue terrier', 184: 'Irish terrier', 185: 'Norfolk terrier', 186: 'Norwich terrier', 187: 'Yorkshire terrier', 188: 'wire-haired fox terrier', 189: 'Lakeland terrier', 190: 'Sealyham terrier, Sealyham', 191: 'Airedale, Airedale terrier', 192: 'cairn, cairn terrier', 193: 'Australian terrier', 194: 'Dandie Dinmont, Dandie Dinmont terrier', 195: 'Boston bull, Boston terrier', 196: 'miniature schnauzer', 197: 'giant schnauzer', 198: 'standard schnauzer', 199: 'Scotch terrier, Scottish terrier, Scottie', 200: 'Tibetan terrier, chrysanthemum dog', 201: 'silky terrier, Sydney silky', 202: 'soft-coated wheaten terrier', 203: 'West Highland white terrier', 204: 'Lhasa, Lhasa apso', 205: 'flat-coated retriever', 206: 'curly-coated retriever', 207: 'golden retriever', 208: 'Labrador retriever', 209: 'Chesapeake Bay retriever', 210: 'German short-haired pointer', 211: 'vizsla, Hungarian pointer', 212: 'English setter', 213: 'Irish setter, red setter', 214: 'Gordon setter', 215: 'Brittany spaniel', 216: 'clumber, clumber spaniel', 217: 'English springer, English springer spaniel', 218: 'Welsh springer spaniel', 219: 'cocker spaniel, English cocker spaniel, cocker', 220: 'Sussex spaniel', 221: 'Irish water spaniel', 222: 'kuvasz', 223: 'schipperke', 224: 'groenendael', 225: 'malinois', 226: 'briard', 227: 'kelpie', 228: 'komondor', 229: 'Old English sheepdog, bobtail', 230: 'Shetland sheepdog, Shetland sheep dog, Shetland', 231: 'collie', 232: 'Border collie', 233: 'Bouvier des Flandres, Bouviers des Flandres', 234: 'Rottweiler', 235: 'German shepherd, German shepherd dog, German police dog, alsatian', 236: 'Doberman, Doberman pinscher', 237: 'miniature pinscher', 238: 'Greater Swiss Mountain dog', 239: 'Bernese mountain dog', 240: 'Appenzeller', 241: 'EntleBucher', 242: 'boxer', 243: 'bull mastiff', 244: 'Tibetan mastiff', 245: 'French bulldog', 246: 'Great Dane', 247: 'Saint Bernard, St Bernard', 248: 'Eskimo dog, husky', 249: 'malamute, malemute, Alaskan malamute', 250: 'Siberian husky', 251: 'dalmatian, coach dog, carriage dog', 252: 'affenpinscher, monkey pinscher, monkey dog', 253: 'basenji', 254: 'pug, pug-dog', 255: 'Leonberg', 256: 'Newfoundland, Newfoundland dog', 257: 'Great Pyrenees', 258: 'Samoyed, Samoyede', 259: 'Pomeranian', 260: 'chow, chow chow', 261: 'keeshond', 262: 'Brabancon griffon', 263: 'Pembroke, Pembroke Welsh corgi', 264: 'Cardigan, Cardigan Welsh corgi', 265: 'toy poodle', 266: 'miniature poodle', 267: 'standard poodle', 268: 'Mexican hairless', 269: 'timber wolf, grey wolf, gray wolf, Canis lupus', 270: 'white wolf, Arctic wolf, Canis lupus tundrarum', 271: 'red wolf, maned wolf, Canis rufus, Canis niger', 272: 'coyote, prairie wolf, brush wolf, Canis latrans', 273: 'dingo, warrigal, warragal, Canis dingo', 274: 'dhole, Cuon alpinus', 275: 'African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus', 276: 'hyena, hyaena', 277: 'red fox, Vulpes vulpes', 278: 'kit fox, Vulpes macrotis', 279: 'Arctic fox, white fox, Alopex lagopus', 280: 'grey fox, gray fox, Urocyon cinereoargenteus', 281: 'tabby, tabby cat', 282: 'tiger cat', 283: 'Persian cat', 284: 'Siamese cat, Siamese', 285: 'Egyptian cat', 286: 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor', 287: 'lynx, catamount', 288: 'leopard, Panthera pardus', 289: 'snow leopard, ounce, Panthera uncia', 290: 'jaguar, panther, Panthera onca, Felis onca', 291: 'lion, king of beasts, Panthera leo', 292: 'tiger, Panthera tigris', 293: 'cheetah, chetah, Acinonyx jubatus', 294: 'brown bear, bruin, Ursus arctos', 295: 'American black bear, black bear, Ursus americanus, Euarctos americanus', 296: 'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus', 297: 'sloth bear, Melursus ursinus, Ursus ursinus', 298: 'mongoose', 299: 'meerkat, mierkat', 300: 'tiger beetle', 301: 'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle', 302: 'ground beetle, carabid beetle', 303: 'long-horned beetle, longicorn, longicorn beetle', 304: 'leaf beetle, chrysomelid', 305: 'dung beetle', 306: 'rhinoceros beetle', 307: 'weevil', 308: 'fly', 309: 'bee', 310: 'ant, emmet, pismire', 311: 'grasshopper, hopper', 312: 'cricket', 313: 'walking stick, walkingstick, stick insect', 314: 'cockroach, roach', 315: 'mantis, mantid', 316: 'cicada, cicala', 317: 'leafhopper', 318: 'lacewing, lacewing fly', 319: "dragonfly, darning needle, devil's darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk", 320: 'damselfly', 321: 'admiral', 322: 'ringlet, ringlet butterfly', 323: 'monarch, monarch butterfly, milkweed butterfly, Danaus plexippus', 324: 'cabbage butterfly', 325: 'sulphur butterfly, sulfur butterfly', 326: 'lycaenid, lycaenid butterfly', 327: 'starfish, sea star', 328: 'sea urchin', 329: 'sea cucumber, holothurian', 330: 'wood rabbit, cottontail, cottontail rabbit', 331: 'hare', 332: 'Angora, Angora rabbit', 333: 'hamster', 334: 'porcupine, hedgehog', 335: 'fox squirrel, eastern fox squirrel, Sciurus niger', 336: 'marmot', 337: 'beaver', 338: 'guinea pig, Cavia cobaya', 339: 'sorrel', 340: 'zebra', 341: 'hog, pig, grunter, squealer, Sus scrofa', 342: 'wild boar, boar, Sus scrofa', 343: 'warthog', 344: 'hippopotamus, hippo, river horse, Hippopotamus amphibius', 345: 'ox', 346: 'water buffalo, water ox, Asiatic buffalo, Bubalus bubalis', 347: 'bison', 348: 'ram, tup', 349: 'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis', 350: 'ibex, Capra ibex', 351: 'hartebeest', 352: 'impala, Aepyceros melampus', 353: 'gazelle', 354: 'Arabian camel, dromedary, Camelus dromedarius', 355: 'llama', 356: 'weasel', 357: 'mink', 358: 'polecat, fitch, foulmart, foumart, Mustela putorius', 359: 'black-footed ferret, ferret, Mustela nigripes', 360: 'otter', 361: 'skunk, polecat, wood pussy', 362: 'badger', 363: 'armadillo', 364: 'three-toed sloth, ai, Bradypus tridactylus', 365: 'orangutan, orang, orangutang, Pongo pygmaeus', 366: 'gorilla, Gorilla gorilla', 367: 'chimpanzee, chimp, Pan troglodytes', 368: 'gibbon, Hylobates lar', 369: 'siamang, Hylobates syndactylus, Symphalangus syndactylus', 370: 'guenon, guenon monkey', 371: 'patas, hussar monkey, Erythrocebus patas', 372: 'baboon', 373: 'macaque', 374: 'langur', 375: 'colobus, colobus monkey', 376: 'proboscis monkey, Nasalis larvatus', 377: 'marmoset', 378: 'capuchin, ringtail, Cebus capucinus', 379: 'howler monkey, howler', 380: 'titi, titi monkey', 381: 'spider monkey, Ateles geoffroyi', 382: 'squirrel monkey, Saimiri sciureus', 383: 'Madagascar cat, ring-tailed lemur, Lemur catta', 384: 'indri, indris, Indri indri, Indri brevicaudatus', 385: 'Indian elephant, Elephas maximus', 386: 'African elephant, Loxodonta africana', 387: 'lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens', 388: 'giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca', 389: 'barracouta, snoek', 390: 'eel', 391: 'coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch', 392: 'rock beauty, Holocanthus tricolor', 393: 'anemone fish', 394: 'sturgeon', 395: 'gar, garfish, garpike, billfish, Lepisosteus osseus', 396: 'lionfish', 397: 'puffer, pufferfish, blowfish, globefish', 398: 'abacus', 399: 'abaya', 400: "academic gown, academic robe, judge's robe", 401: 'accordion, piano accordion, squeeze box', 402: 'acoustic guitar', 403: 'aircraft carrier, carrier, flattop, attack aircraft carrier', 404: 'airliner', 405: 'airship, dirigible', 406: 'altar', 407: 'ambulance', 408: 'amphibian, amphibious vehicle', 409: 'analog clock', 410: 'apiary, bee house', 411: 'apron', 412: 'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 413: 'assault rifle, assault gun', 414: 'backpack, back pack, knapsack, packsack, rucksack, haversack', 415: 'bakery, bakeshop, bakehouse', 416: 'balance beam, beam', 417: 'balloon', 418: 'ballpoint, ballpoint pen, ballpen, Biro', 419: 'Band Aid', 420: 'banjo', 421: 'bannister, banister, balustrade, balusters, handrail', 422: 'barbell', 423: 'barber chair', 424: 'barbershop', 425: 'barn', 426: 'barometer', 427: 'barrel, cask', 428: 'barrow, garden cart, lawn cart, wheelbarrow', 429: 'baseball', 430: 'basketball', 431: 'bassinet', 432: 'bassoon', 433: 'bathing cap, swimming cap', 434: 'bath towel', 435: 'bathtub, bathing tub, bath, tub', 436: 'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon', 437: 'beacon, lighthouse, beacon light, pharos', 438: 'beaker', 439: 'bearskin, busby, shako', 440: 'beer bottle', 441: 'beer glass', 442: 'bell cote, bell cot', 443: 'bib', 444: 'bicycle-built-for-two, tandem bicycle, tandem', 445: 'bikini, two-piece', 446: 'binder, ring-binder', 447: 'binoculars, field glasses, opera glasses', 448: 'birdhouse', 449: 'boathouse', 450: 'bobsled, bobsleigh, bob', 451: 'bolo tie, bolo, bola tie, bola', 452: 'bonnet, poke bonnet', 453: 'bookcase', 454: 'bookshop, bookstore, bookstall', 455: 'bottlecap', 456: 'bow', 457: 'bow tie, bow-tie, bowtie', 458: 'brass, memorial tablet, plaque', 459: 'brassiere, bra, bandeau', 460: 'breakwater, groin, groyne, mole, bulwark, seawall, jetty', 461: 'breastplate, aegis, egis', 462: 'broom', 463: 'bucket, pail', 464: 'buckle', 465: 'bulletproof vest', 466: 'bullet train, bullet', 467: 'butcher shop, meat market', 468: 'cab, hack, taxi, taxicab', 469: 'caldron, cauldron', 470: 'candle, taper, wax light', 471: 'cannon', 472: 'canoe', 473: 'can opener, tin opener', 474: 'cardigan', 475: 'car mirror', 476: 'carousel, carrousel, merry-go-round, roundabout, whirligig', 477: "carpenter's kit, tool kit", 478: 'carton', 479: 'car wheel', 480: 'cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', 481: 'cassette', 482: 'cassette player', 483: 'castle', 484: 'catamaran', 485: 'CD player', 486: 'cello, violoncello', 487: 'cellular telephone, cellular phone, cellphone, cell, mobile phone', 488: 'chain', 489: 'chainlink fence', 490: 'chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour', 491: 'chain saw, chainsaw', 492: 'chest', 493: 'chiffonier, commode', 494: 'chime, bell, gong', 495: 'china cabinet, china closet', 496: 'Christmas stocking', 497: 'church, church building', 498: 'cinema, movie theater, movie theatre, movie house, picture palace', 499: 'cleaver, meat cleaver, chopper', 500: 'cliff dwelling', 501: 'cloak', 502: 'clog, geta, patten, sabot', 503: 'cocktail shaker', 504: 'coffee mug', 505: 'coffeepot', 506: 'coil, spiral, volute, whorl, helix', 507: 'combination lock', 508: 'computer keyboard, keypad', 509: 'confectionery, confectionary, candy store', 510: 'container ship, containership, container vessel', 511: 'convertible', 512: 'corkscrew, bottle screw', 513: 'cornet, horn, trumpet, trump', 514: 'cowboy boot', 515: 'cowboy hat, ten-gallon hat', 516: 'cradle', 517: 'crane', 518: 'crash helmet', 519: 'crate', 520: 'crib, cot', 521: 'Crock Pot', 522: 'croquet ball', 523: 'crutch', 524: 'cuirass', 525: 'dam, dike, dyke', 526: 'desk', 527: 'desktop computer', 528: 'dial telephone, dial phone', 529: 'diaper, nappy, napkin', 530: 'digital clock', 531: 'digital watch', 532: 'dining table, board', 533: 'dishrag, dishcloth', 534: 'dishwasher, dish washer, dishwashing machine', 535: 'disk brake, disc brake', 536: 'dock, dockage, docking facility', 537: 'dogsled, dog sled, dog sleigh', 538: 'dome', 539: 'doormat, welcome mat', 540: 'drilling platform, offshore rig', 541: 'drum, membranophone, tympan', 542: 'drumstick', 543: 'dumbbell', 544: 'Dutch oven', 545: 'electric fan, blower', 546: 'electric guitar', 547: 'electric locomotive', 548: 'entertainment center', 549: 'envelope', 550: 'espresso maker', 551: 'face powder', 552: 'feather boa, boa', 553: 'file, file cabinet, filing cabinet', 554: 'fireboat', 555: 'fire engine, fire truck', 556: 'fire screen, fireguard', 557: 'flagpole, flagstaff', 558: 'flute, transverse flute', 559: 'folding chair', 560: 'football helmet', 561: 'forklift', 562: 'fountain', 563: 'fountain pen', 564: 'four-poster', 565: 'freight car', 566: 'French horn, horn', 567: 'frying pan, frypan, skillet', 568: 'fur coat', 569: 'garbage truck, dustcart', 570: 'gasmask, respirator, gas helmet', 571: 'gas pump, gasoline pump, petrol pump, island dispenser', 572: 'goblet', 573: 'go-kart', 574: 'golf ball', 575: 'golfcart, golf cart', 576: 'gondola', 577: 'gong, tam-tam', 578: 'gown', 579: 'grand piano, grand', 580: 'greenhouse, nursery, glasshouse', 581: 'grille, radiator grille', 582: 'grocery store, grocery, food market, market', 583: 'guillotine', 584: 'hair slide', 585: 'hair spray', 586: 'half track', 587: 'hammer', 588: 'hamper', 589: 'hand blower, blow dryer, blow drier, hair dryer, hair drier', 590: 'hand-held computer, hand-held microcomputer', 591: 'handkerchief, hankie, hanky, hankey', 592: 'hard disc, hard disk, fixed disk', 593: 'harmonica, mouth organ, harp, mouth harp', 594: 'harp', 595: 'harvester, reaper', 596: 'hatchet', 597: 'holster', 598: 'home theater, home theatre', 599: 'honeycomb', 600: 'hook, claw', 601: 'hoopskirt, crinoline', 602: 'horizontal bar, high bar', 603: 'horse cart, horse-cart', 604: 'hourglass', 605: 'iPod', 606: 'iron, smoothing iron', 607: "jack-o'-lantern", 608: 'jean, blue jean, denim', 609: 'jeep, landrover', 610: 'jersey, T-shirt, tee shirt', 611: 'jigsaw puzzle', 612: 'jinrikisha, ricksha, rickshaw', 613: 'joystick', 614: 'kimono', 615: 'knee pad', 616: 'knot', 617: 'lab coat, laboratory coat', 618: 'ladle', 619: 'lampshade, lamp shade', 620: 'laptop, laptop computer', 621: 'lawn mower, mower', 622: 'lens cap, lens cover', 623: 'letter opener, paper knife, paperknife', 624: 'library', 625: 'lifeboat', 626: 'lighter, light, igniter, ignitor', 627: 'limousine, limo', 628: 'liner, ocean liner', 629: 'lipstick, lip rouge', 630: 'Loafer', 631: 'lotion', 632: 'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', 633: "loupe, jeweler's loupe", 634: 'lumbermill, sawmill', 635: 'magnetic compass', 636: 'mailbag, postbag', 637: 'mailbox, letter box', 638: 'maillot', 639: 'maillot, tank suit', 640: 'manhole cover', 641: 'maraca', 642: 'marimba, xylophone', 643: 'mask', 644: 'matchstick', 645: 'maypole', 646: 'maze, labyrinth', 647: 'measuring cup', 648: 'medicine chest, medicine cabinet', 649: 'megalith, megalithic structure', 650: 'microphone, mike', 651: 'microwave, microwave oven', 652: 'military uniform', 653: 'milk can', 654: 'minibus', 655: 'miniskirt, mini', 656: 'minivan', 657: 'missile', 658: 'mitten', 659: 'mixing bowl', 660: 'mobile home, manufactured home', 661: 'Model T', 662: 'modem', 663: 'monastery', 664: 'monitor', 665: 'moped', 666: 'mortar', 667: 'mortarboard', 668: 'mosque', 669: 'mosquito net', 670: 'motor scooter, scooter', 671: 'mountain bike, all-terrain bike, off-roader', 672: 'mountain tent', 673: 'mouse, computer mouse', 674: 'mousetrap', 675: 'moving van', 676: 'muzzle', 677: 'nail', 678: 'neck brace', 679: 'necklace', 680: 'nipple', 681: 'notebook, notebook computer', 682: 'obelisk', 683: 'oboe, hautboy, hautbois', 684: 'ocarina, sweet potato', 685: 'odometer, hodometer, mileometer, milometer', 686: 'oil filter', 687: 'organ, pipe organ', 688: 'oscilloscope, scope, cathode-ray oscilloscope, CRO', 689: 'overskirt', 690: 'oxcart', 691: 'oxygen mask', 692: 'packet', 693: 'paddle, boat paddle', 694: 'paddlewheel, paddle wheel', 695: 'padlock', 696: 'paintbrush', 697: "pajama, pyjama, pj's, jammies", 698: 'palace', 699: 'panpipe, pandean pipe, syrinx', 700: 'paper towel', 701: 'parachute, chute', 702: 'parallel bars, bars', 703: 'park bench', 704: 'parking meter', 705: 'passenger car, coach, carriage', 706: 'patio, terrace', 707: 'pay-phone, pay-station', 708: 'pedestal, plinth, footstall', 709: 'pencil box, pencil case', 710: 'pencil sharpener', 711: 'perfume, essence', 712: 'Petri dish', 713: 'photocopier', 714: 'pick, plectrum, plectron', 715: 'pickelhaube', 716: 'picket fence, paling', 717: 'pickup, pickup truck', 718: 'pier', 719: 'piggy bank, penny bank', 720: 'pill bottle', 721: 'pillow', 722: 'ping-pong ball', 723: 'pinwheel', 724: 'pirate, pirate ship', 725: 'pitcher, ewer', 726: "plane, carpenter's plane, woodworking plane", 727: 'planetarium', 728: 'plastic bag', 729: 'plate rack', 730: 'plow, plough', 731: "plunger, plumber's helper", 732: 'Polaroid camera, Polaroid Land camera', 733: 'pole', 734: 'police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria', 735: 'poncho', 736: 'pool table, billiard table, snooker table', 737: 'pop bottle, soda bottle', 738: 'pot, flowerpot', 739: "potter's wheel", 740: 'power drill', 741: 'prayer rug, prayer mat', 742: 'printer', 743: 'prison, prison house', 744: 'projectile, missile', 745: 'projector', 746: 'puck, hockey puck', 747: 'punching bag, punch bag, punching ball, punchball', 748: 'purse', 749: 'quill, quill pen', 750: 'quilt, comforter, comfort, puff', 751: 'racer, race car, racing car', 752: 'racket, racquet', 753: 'radiator', 754: 'radio, wireless', 755: 'radio telescope, radio reflector', 756: 'rain barrel', 757: 'recreational vehicle, RV, R.V.', 758: 'reel', 759: 'reflex camera', 760: 'refrigerator, icebox', 761: 'remote control, remote', 762: 'restaurant, eating house, eating place, eatery', 763: 'revolver, six-gun, six-shooter', 764: 'rifle', 765: 'rocking chair, rocker', 766: 'rotisserie', 767: 'rubber eraser, rubber, pencil eraser', 768: 'rugby ball', 769: 'rule, ruler', 770: 'running shoe', 771: 'safe', 772: 'safety pin', 773: 'saltshaker, salt shaker', 774: 'sandal', 775: 'sarong', 776: 'sax, saxophone', 777: 'scabbard', 778: 'scale, weighing machine', 779: 'school bus', 780: 'schooner', 781: 'scoreboard', 782: 'screen, CRT screen', 783: 'screw', 784: 'screwdriver', 785: 'seat belt, seatbelt', 786: 'sewing machine', 787: 'shield, buckler', 788: 'shoe shop, shoe-shop, shoe store', 789: 'shoji', 790: 'shopping basket', 791: 'shopping cart', 792: 'shovel', 793: 'shower cap', 794: 'shower curtain', 795: 'ski', 796: 'ski mask', 797: 'sleeping bag', 798: 'slide rule, slipstick', 799: 'sliding door', 800: 'slot, one-armed bandit', 801: 'snorkel', 802: 'snowmobile', 803: 'snowplow, snowplough', 804: 'soap dispenser', 805: 'soccer ball', 806: 'sock', 807: 'solar dish, solar collector, solar furnace', 808: 'sombrero', 809: 'soup bowl', 810: 'space bar', 811: 'space heater', 812: 'space shuttle', 813: 'spatula', 814: 'speedboat', 815: "spider web, spider's web", 816: 'spindle', 817: 'sports car, sport car', 818: 'spotlight, spot', 819: 'stage', 820: 'steam locomotive', 821: 'steel arch bridge', 822: 'steel drum', 823: 'stethoscope', 824: 'stole', 825: 'stone wall', 826: 'stopwatch, stop watch', 827: 'stove', 828: 'strainer', 829: 'streetcar, tram, tramcar, trolley, trolley car', 830: 'stretcher', 831: 'studio couch, day bed', 832: 'stupa, tope', 833: 'submarine, pigboat, sub, U-boat', 834: 'suit, suit of clothes', 835: 'sundial', 836: 'sunglass', 837: 'sunglasses, dark glasses, shades', 838: 'sunscreen, sunblock, sun blocker', 839: 'suspension bridge', 840: 'swab, swob, mop', 841: 'sweatshirt', 842: 'swimming trunks, bathing trunks', 843: 'swing', 844: 'switch, electric switch, electrical switch', 845: 'syringe', 846: 'table lamp', 847: 'tank, army tank, armored combat vehicle, armoured combat vehicle', 848: 'tape player', 849: 'teapot', 850: 'teddy, teddy bear', 851: 'television, television system', 852: 'tennis ball', 853: 'thatch, thatched roof', 854: 'theater curtain, theatre curtain', 855: 'thimble', 856: 'thresher, thrasher, threshing machine', 857: 'throne', 858: 'tile roof', 859: 'toaster', 860: 'tobacco shop, tobacconist shop, tobacconist', 861: 'toilet seat', 862: 'torch', 863: 'totem pole', 864: 'tow truck, tow car, wrecker', 865: 'toyshop', 866: 'tractor', 867: 'trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi', 868: 'tray', 869: 'trench coat', 870: 'tricycle, trike, velocipede', 871: 'trimaran', 872: 'tripod', 873: 'triumphal arch', 874: 'trolleybus, trolley coach, trackless trolley', 875: 'trombone', 876: 'tub, vat', 877: 'turnstile', 878: 'typewriter keyboard', 879: 'umbrella', 880: 'unicycle, monocycle', 881: 'upright, upright piano', 882: 'vacuum, vacuum cleaner', 883: 'vase', 884: 'vault', 885: 'velvet', 886: 'vending machine', 887: 'vestment', 888: 'viaduct', 889: 'violin, fiddle', 890: 'volleyball', 891: 'waffle iron', 892: 'wall clock', 893: 'wallet, billfold, notecase, pocketbook', 894: 'wardrobe, closet, press', 895: 'warplane, military plane', 896: 'washbasin, handbasin, washbowl, lavabo, wash-hand basin', 897: 'washer, automatic washer, washing machine', 898: 'water bottle', 899: 'water jug', 900: 'water tower', 901: 'whiskey jug', 902: 'whistle', 903: 'wig', 904: 'window screen', 905: 'window shade', 906: 'Windsor tie', 907: 'wine bottle', 908: 'wing', 909: 'wok', 910: 'wooden spoon', 911: 'wool, woolen, woollen', 912: 'worm fence, snake fence, snake-rail fence, Virginia fence', 913: 'wreck', 914: 'yawl', 915: 'yurt', 916: 'web site, website, internet site, site', 917: 'comic book', 918: 'crossword puzzle, crossword', 919: 'street sign', 920: 'traffic light, traffic signal, stoplight', 921: 'book jacket, dust cover, dust jacket, dust wrapper', 922: 'menu', 923: 'plate', 924: 'guacamole', 925: 'consomme', 926: 'hot pot, hotpot', 927: 'trifle', 928: 'ice cream, icecream', 929: 'ice lolly, lolly, lollipop, popsicle', 930: 'French loaf', 931: 'bagel, beigel', 932: 'pretzel', 933: 'cheeseburger', 934: 'hotdog, hot dog, red hot', 935: 'mashed potato', 936: 'head cabbage', 937: 'broccoli', 938: 'cauliflower', 939: 'zucchini, courgette', 940: 'spaghetti squash', 941: 'acorn squash', 942: 'butternut squash', 943: 'cucumber, cuke', 944: 'artichoke, globe artichoke', 945: 'bell pepper', 946: 'cardoon', 947: 'mushroom', 948: 'Granny Smith', 949: 'strawberry', 950: 'orange', 951: 'lemon', 952: 'fig', 953: 'pineapple, ananas', 954: 'banana', 955: 'jackfruit, jak, jack', 956: 'custard apple', 957: 'pomegranate', 958: 'hay', 959: 'carbonara', 960: 'chocolate sauce, chocolate syrup', 961: 'dough', 962: 'meat loaf, meatloaf', 963: 'pizza, pizza pie', 964: 'potpie', 965: 'burrito', 966: 'red wine', 967: 'espresso', 968: 'cup', 969: 'eggnog', 970: 'alp', 971: 'bubble', 972: 'cliff, drop, drop-off', 973: 'coral reef', 974: 'geyser', 975: 'lakeside, lakeshore', 976: 'promontory, headland, head, foreland', 977: 'sandbar, sand bar', 978: 'seashore, coast, seacoast, sea-coast', 979: 'valley, vale', 980: 'volcano', 981: 'ballplayer, baseball player', 982: 'groom, bridegroom', 983: 'scuba diver', 984: 'rapeseed', 985: 'daisy', 986: "yellow lady's slipper, yellow lady-slipper, Cypripedium calceolus, Cypripedium parviflorum", 987: 'corn', 988: 'acorn', 989: 'hip, rose hip, rosehip', 990: 'buckeye, horse chestnut, conker', 991: 'coral fungus', 992: 'agaric', 993: 'gyromitra', 994: 'stinkhorn, carrion fungus', 995: 'earthstar', 996: 'hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa', 997: 'bolete', 998: 'ear, spike, capitulum', 999: 'toilet tissue, toilet paper, bathroom tissue'};

# %%
# Define root directory if your data is on disk
root_dir = "/content/dog_classification_data-20210518T100018Z-001/dog_classification_data"

# %% [markdown]
# You can also pur your data on Google Drive (which is good if you want to train on Google Colab)

# %%
# Define root directory from Google Drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b460bfea9195> in <module>()
#       1 # Define root directory from Google Drive
#       2 from google.colab import drive
# ----> 3 drive.mount("/content/drive")
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
# !unzip "/content/drive/MyDrive/dog_classification_data-20210518T100018Z-001.zip"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03678.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03681.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03682.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03683.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03685.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03686.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03687.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03688.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03689.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03690.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03691.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03692.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03693.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03694.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03695.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03696.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03699.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03700.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03701.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03704.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03705.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03706.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03707.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03708.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03709.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03710.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03711.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03713.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03714.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03716.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03717.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03718.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03719.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03720.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03721.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03722.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03723.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03725.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03726.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03727.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/052.Clumber_spaniel/Clumber_spaniel_03728.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03729.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03730.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03731.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03732.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03734.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03735.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03736.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03737.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03738.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03739.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03741.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03744.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03745.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03746.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03747.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03749.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03750.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03751.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03752.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03753.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03754.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03755.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03756.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03757.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03758.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03760.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03761.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03762.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03763.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03764.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03767.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03768.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03770.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03771.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03772.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03773.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03774.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03777.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03778.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03780.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03781.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03782.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03783.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03784.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03785.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03786.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/053.Cocker_spaniel/Cocker_spaniel_03787.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03788.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03789.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03792.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03793.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03795.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03796.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03798.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03799.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03800.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03801.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03802.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03803.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03804.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03805.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03806.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03807.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03808.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03809.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03810.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03811.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03812.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03813.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03814.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03815.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03816.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03817.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03818.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03820.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03821.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03822.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03823.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03824.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03825.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03826.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03827.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03828.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03829.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03830.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03831.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03832.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03836.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03837.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03838.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03839.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03840.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03841.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03843.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03844.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03845.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03846.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03847.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03848.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03850.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03852.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03853.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03856.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/054.Collie/Collie_03857.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03859.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03860.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03861.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03862.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03864.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03865.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03866.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03868.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03871.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03873.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03874.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03875.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03876.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03877.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03878.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03879.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03880.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03883.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03886.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03888.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03890.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03891.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03892.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03894.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03895.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03896.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03897.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03898.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03899.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03900.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03902.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03903.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03904.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03905.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03906.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03907.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03908.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03909.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03910.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03911.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03912.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03913.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03914.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03915.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03916.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03917.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03918.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03919.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03920.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/055.Curly-coated_retriever/Curly-coated_retriever_03921.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03922.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03923.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03924.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03925.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03927.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03928.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03930.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03931.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03932.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03933.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03934.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03935.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03937.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03938.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03939.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03940.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03941.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03942.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03943.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03944.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03945.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03947.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03948.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03949.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03950.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03951.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03952.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03954.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03955.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03956.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03957.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03958.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03959.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03961.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03962.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03963.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03964.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03965.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03968.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03969.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03970.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03971.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03972.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03974.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03975.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03976.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03977.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03978.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03979.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03980.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03982.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03983.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03984.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03986.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03988.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03989.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03990.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03992.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03993.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03994.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03998.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_03999.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_04000.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_04001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/056.Dachshund/Dachshund_04002.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04004.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04007.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04008.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04009.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04010.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04011.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04012.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04013.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04016.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04017.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04018.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04019.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04022.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04023.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04024.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04025.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04026.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04027.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04028.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04029.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04031.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04032.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04033.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04034.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04035.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04036.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04037.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04038.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04039.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04040.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04041.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04042.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04043.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04044.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04045.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04046.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04048.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04049.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04050.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04052.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04053.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04054.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04055.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04061.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04062.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04063.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04064.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04065.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04067.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04068.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04069.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04070.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04071.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04072.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04073.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04074.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04075.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04077.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04078.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04080.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04081.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04082.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04083.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04084.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04085.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04086.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04087.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04089.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04090.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04091.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/057.Dalmatian/Dalmatian_04092.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/058.Dandie_dinmont_terrier/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04093.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04094.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_images/train/058.Dandie_dinmont_terrier/Dandie_dinmont_terrier_04095.jpg
# ...
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Keith_Foulke_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Linda_Amicangioli_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Lindsay_Davenport_0005.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Lucas_Wysocki_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Matt_Welsh_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Mel_Brooks_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Mike_Krzyzewski_0004.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Mireya_Moscoso_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Muammar_Gaddafi_0002.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Natasha_Lyonne_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Nicolas_Lapentti_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Norah_Jones_0015.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Penny_Lancaster_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Platon_Lebedev_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Ray_Liotta_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Robert_Zoellick_0003.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Sargis_Sargsian_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Ted_Nolan_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Tian_Liang_0001.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Tony_Blair_0021.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Tony_Blair_0127.jpg
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/dog_vs_human/human/Vojislav_Seselj_0001.jpg
#    creating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00000388.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00001688.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00004135.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00004943.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00006301.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00006684.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00008284.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00009739.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00011224.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00011247.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00011700.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00013114.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00013264.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00015927.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00017102.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00017323.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00017344.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00020215.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00021278.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00022228.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00022453.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00022897.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00023612.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00024689.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00027786.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00028941.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00029601.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00030031.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00030254.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00030517.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00030647.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00031504.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00031569.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00035017.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00035558.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00036698.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00038114.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00038519.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00040227.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00040293.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00041693.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00042311.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00043008.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00044332.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00044842.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00045326.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00045370.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00046779.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00047549.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00047794.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00050053.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00050265.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00051747.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00053701.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00054014.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00054360.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00054923.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00056001.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00057815.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00058452.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00059864.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00061901.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00061916.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00063351.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00063589.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00064228.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00064820.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00064866.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00068788.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00070923.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00071842.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00072143.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00073186.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00076112.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00076394.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00077813.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00077834.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00078371.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00079968.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00081637.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00082068.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00082598.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00082860.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00084189.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00084320.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00085050.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00086177.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00086663.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00087216.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00087668.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00087830.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00089026.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00089263.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00089377.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00090685.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00092603.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00093808.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00095824.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00098094.JPEG
#   inflating: dog_classification_data-20210518T100018Z-001/dog_classification_data/imagenet_samples/ILSVRC2012_test_00098782.JPEG

# %% [markdown]
# #### Making predictions with Inception
#
# * Load some images from the `imagenet_samples` directory
# * Process them with the Inception network
# * Get the predicted label
# * Get the class name

# %%
# Imports
from PIL import Image
from torch.autograd import Variable
import matplotlib.pyplot as plt
from glob import glob
import os
import random
# %matplotlib inline

# Get random image
image_paths = glob(os.path.join(root_dir, "imagenet_samples", "*"))
random.shuffle(image_paths)
image_path = image_paths[0]
# Load image
img = Image.open(image_path).convert("RGB")
# Show image
plt.imshow(img)
plt.axis('off')

# Transform image
img = inception_transform(img).unsqueeze(0)
img = Variable(img)
# Compute Inception predicted label
inception.eval()
prediction = inception(img)
_, pred = torch.max(prediction, 1)
pred = pred.item()
# Print predicted class
print(f"Predicted: {class_names[pred]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-688123c4e7f3> in <module>()
#      19
#      20 # Transform image
# ---> 21 img = inception_transform(img).unsqueeze(0)
#      22 img = Variable(img)
#      23 # Compute Inception predicted label
#
# NameError: name 'inception_transform' is not defined

# %% [markdown]
# While looking at the class dictionary, you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268 (inclusive), to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained Inception model, we need only check if the predicted label is a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).
#
# To test your dog detector, use some images from the `dog_vs_human` directory.

# %%
# Dog detector: returns "True" if a dog is detected in the input image
def dog_detector(pil_img):
    # Transform image
    img = inception_transform(pil_img).unsqueeze(0)
    img = Variable(img)
    # Compute Inception predicted label
    inception.eval()
    prediction = inception(img)
    _, pred = torch.max(prediction, 1)
    pred = pred.item()
    # Return
    if pred > 150 and pred < 269:
      return True
    else:
      return False

# %% [markdown]
# Test dog detector

# %%
# Get random image from dog/image dataset
image_paths = glob(os.path.join(root_dir, "dog_vs_human", "*", "*jpg"))
random.shuffle(image_paths)
image_path = image_paths[0]
# Load image
img = Image.open(image_path).convert("RGB")
# Show image
plt.imshow(img)
plt.axis('off')

# Are there dogs?
dogs_found = dog_detector(img)
print(f"Dogs found: {dogs_found}")
# Out:
# Dogs found: False

# %% [markdown]
# ## Step 2: Create a CNN to Classify Dog Breeds (from scratch)
#
# Now, you will create a CNN that classifies dog breeds.  You must create your CNN *from scratch*.
#
# The task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="https://i.ibb.co/QJhdgfm/Brittany-02625.jpg" width="200"> | <img src="https://i.ibb.co/kmdJkcT/Welsh-springer-spaniel-08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="https://i.ibb.co/3RCBYyQ/Curly-coated-retriever-03896.jpg" width="200"> | <img src="https://i.ibb.co/SNwPXdt/American-water-spaniel-00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | - | -
# <img src="https://i.ibb.co/kgTpzHj/Labrador-retriever-06457.jpg" width="150"> | <img src="https://i.ibb.co/8YBbX9D/Labrador-retriever-06455.jpg" width="240"> | <img src="https://i.ibb.co/qkhv71H/Labrador-retriever-06449.jpg" width="220">

# %% [markdown]
# #### Datasets
#
# First of all, let's create our dataset and data loaders. We will use training, validation and test sets. You will measure your best model based on its performance on the validation set. **REMEMBER**: your best test performance is not the highest test accuracy you achieve, but it's the test accuracy that you achieve at the highest validation accuracy!
#
# In order to load our data, we will use the `ImageFolder` class. This class receives as argument the path to a directory which contains **one sub-directory per class**. For example, you can see that the `dog_images/train` directory in the Google Drive share has this structure. The class will return a `Dataset` instance, with the usual interface (`len` to get the number of samples, `[]` to access each sample), that you can pass to a `DataLoader` instance.
#
# Also, note that you training transformation (with data augmentation) will be different from your test transformations (without data augmentation: for example, you don't need random cropping).

# %%
# Imports
import torch
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
from torch.utils.data import DataLoader

# Data loading options
batch_size = 64
load_size = 230
crop_size = 224
norm_mean = (0.5, 0.5, 0.5)
norm_std = (0.5, 0.5, 0.5)

# Train transform
train_transform = T.Compose([
        T.Resize(load_size),
        T.RandomCrop(crop_size),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
        T.Normalize(norm_mean, norm_std)
])

# Test transform
test_transform = T.Compose([
        T.Resize(load_size),
        T.CenterCrop(crop_size),
        T.ToTensor(),
        T.Normalize(norm_mean, norm_std) 
])

# Instantiate datasets
dog_train_dataset = ImageFolder(os.path.join(root_dir, "dog_images", "train"), transform=train_transform)
dog_val_dataset = ImageFolder(os.path.join(root_dir, "dog_images", "valid"), transform=test_transform)
dog_test_dataset = ImageFolder(os.path.join(root_dir, "dog_images", "test"), transform=test_transform)

# Get number of classes (we'll need it in the model)
num_classes = len(dog_train_dataset.classes)

# Print dataset statistics
print(f"Num. classes: {num_classes}")
print(f"Num. train samples: {len(dog_train_dataset)}")
print(f"Num. valid. samples: {len(dog_val_dataset)}")
print(f"Num. test samples: {len(dog_test_dataset)}")


# Instantiate data loaders
train_loader = DataLoader(dog_train_dataset, batch_size=batch_size, num_workers=1, shuffle=True)
val_loader   = DataLoader(dog_val_dataset,   batch_size=batch_size, num_workers=1, shuffle=False)
test_loader  = DataLoader(dog_test_dataset,  batch_size=batch_size, num_workers=1, shuffle=False)

loaders = {"train": train_loader,
           "val": val_loader,
           "test": test_loader}
# Out:
# Num. classes: 133
# Num. train samples: 6687
# Num. valid. samples: 835
# Num. test samples: 836

# %% [markdown]
# #### Model definition
#
# Define your CNN architecture.

# %%
# Imports
import torch.nn as nn
import torch.nn.functional as F

# Define model
class Model(nn.Module):
    #
    def __init__(self):
      super().__init__();

      self.conv_layers = nn.Sequential(
          nn.Conv2d(3, 8, kernel_size = 3, padding = 0, stride = 1),
          nn.ReLU(),
          nn.BatchNorm2d(8),
          nn.MaxPool2d(kernel_size=2, stride=2),
          
          nn.Conv2d(8, 16, kernel_size = 3, padding = 0, stride = 1),
          nn.ReLU(),
          nn.BatchNorm2d(16),
          nn.MaxPool2d(kernel_size=2, stride=2),


          nn.Conv2d(16, 32, kernel_size = 3, padding = 0, stride = 1),
          nn.ReLU(),
          nn.BatchNorm2d(32),
          nn.MaxPool2d(kernel_size=2, stride=2),

          nn.Conv2d(32, 64, kernel_size = 3, padding = 0, stride = 1),
          nn.ReLU(),
          nn.BatchNorm2d(64),
          nn.MaxPool2d(kernel_size=2, stride=2),

          nn.Conv2d(64, 128, kernel_size = 3, padding = 0, stride = 1),
          nn.ReLU(),
          nn.BatchNorm2d(128),
          nn.MaxPool2d(kernel_size=2, stride=2),          
      )
      self.fc_layers = nn.Sequential(
          nn.Linear(6272, 2048),     
          nn.Linear(2048, 512),
          nn.Linear(512, num_classes)
      )

    def forward(self, x):
      x = self.conv_layers(x)
      x = x.view(x.size(0), -1)
      x = self.fc_layers(x)
      return x

# %%
# Create model
model = Model()

# %% [markdown]
# When you design your model, you can use the following cell to check that the model correctly processes input images, and also to check the size of the output as you add more layers.

# %%
# Test model output
model.eval()
test_input = dog_train_dataset[0][0].unsqueeze(0)
print("Input data size: ", test_input.shape)
print("Model output size:", model(test_input).size())
# Out:
# Input data size:  torch.Size([1, 3, 290, 290])
# Model output size: torch.Size([1, 133])

# %%
# Move model to device
dev = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(dev)

# %% [markdown]
# You can now train the model.
#
# You are free to use the regular `torch.optim.SGD` optimizer. However, we suggest that you use the `torch.optim.Adam` optimizer: it speeds up the training, and has the same interface as `SGD`.

# %%
# Create optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# Below is a template algorithm for training. You can modify anything you want, but these are the requirements you must meet for the exercise:
# * at each epoch, compute average training loss, training accuracy, validation loss, validation accuracy, test loss, test accuracy;
# * keep a list for each of the above values for all epochs (for plotting);
# * keep track of the test accuracy at the best validation accuracy.

# %%
# Initialize training history
# HINT: here you set up the lists for average loss/accuracy for all epochs
train_loss = []
train_acc = []
val_loss = []
val_acc = []
test_loss = []
test_acc = []
# Initialize best validation accuracy and test accuracy at best validation accuracy
best_val_accuracy = 0
test_accuracy_at_best_val = 0

# %%
# Start training
# HINT:
# - change the number of epochs as you want
# - you can always interrupt training by clicking on the "interrupt kernel" on the toolbar
# - you can set a small number of epochs, train for a while, plot losses, and then train again
# - in general, training for at most 50 epochs will be ok
for epoch in range(10):
    # Initialize variables for computing average loss/accuracy
    sum_loss = {"train": 0, "val": 0, "test": 0}
    sum_acc = {"train": 0, "val": 0, "test": 0}
    # Process each split
    for split in ["train", "val", "test"]:
        # Set network mode (train or eval)
        model.train();
        # Process all data in split
        for  i, (input, labels) in enumerate(loaders[split]):
            # Process each batch
            input = input.to(dev)
            labels = labels.to(dev)
            optimizer.zero_grad()
            pred = model(input)
            loss = F.cross_entropy(pred, labels)
            sum_loss[split] += loss.item()
            if split == "train":
              loss.backward()
              optimizer.step()
            _, pred_labels = pred.max(1)
            sum_acc[split] += (pred_labels == labels).sum().item()/input.size(0)
    # Compute average epoch loss/accuracy
    epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}
    epoch_acc = {split: sum_acc[split]/len(loaders[split]) for split in ["train", "val", "test"]}
    
    train_loss.append(epoch_loss["train"])
    train_acc.append(epoch_acc["train"])
    val_loss.append(epoch_loss["val"])
    val_acc.append(epoch_acc["val"])
    test_loss.append(epoch_loss["test"])
    test_acc.append(epoch_acc["test"])

    print(f"Epoch {epoch+1}:",
          f"TrL={epoch_loss['train']:.4f},",
          f"TrA={epoch_acc['train']:.4f},",
          f"VL={epoch_loss['val']:.4f},",
          f"VA={epoch_acc['val']:.4f},",
          f"TeL={epoch_loss['test']:.4f},",
          f"TeA={epoch_acc['test']:.4f},")
    # Check if we obtained the best validation accuracy
    if epoch_acc["val"] > best_val_accuracy:
        # Update best validation accuracy and test accuracy at best validation
        best_val_accuracy = epoch_acc["val"]
        test_accuracy_at_best_val = epoch_acc["test"]

# %%
# Print test accuracy at best validation accuracy
print(f"Final test accuracy {test_accuracy_at_best_val:.4f}")
# Out:
# Final test accuracy 0.1377

# %%
# Plot loss history
plt.title("Loss")
plt.plot(train_loss, label="train")
plt.plot(val_loss, label="validation")
plt.plot(test_loss, label="test")
plt.legend()
plt.show()

# %%
# Plot accuracy history
plt.title("Accuracy")
plt.plot(train_acc, label="train")
plt.plot(val_acc, label="validation")
plt.plot(test_acc, label="test")
plt.legend()
plt.show()

# %% [markdown]
# After training, let's test the model on random images from the dataset.

# %%
import random

# Get random sample from test set
idx = random.randint(0, len(dog_test_dataset)-1)
input, label = dog_test_dataset[idx]
# Normalize and show image
input_show = (input - input.min())/(input.max() - input.min())
plt.imshow(input_show.permute(1,2,0).numpy())
plt.axis('off')
# Predict class
model.eval()
with torch.no_grad():
    output = model(input.unsqueeze(0).to(dev))
_,pred = output.max(1)
pred = pred.item()
print(f"Predicted: {pred} (correct: {label})")
# Out:
# Predicted: 106 (correct: 106)

# %% [markdown]
# ## Step 3: Fine-tune a CNN
#
# You will now have to fine-tune a pre-trained CNN on your task. This approach is going to give you much better results than training from scratch, because the pre-trained CNN already has learnt meaningful feature maps that you can re-use. Your fine-tuned CNN should attain at least 50% accuracy on the test set.
#
# Our fine-tuned CNN will be based on the AlexNet model. In practice, we will extract the first layers from AlexNet to compute some feature maps. Then you will have to add additional layers compute the final output.

# %%
# Define fine-tuned model
class FineTunedAlexNet(nn.Module):
    
    def __init__(self):
        super().__init__()
        # Load AlexNet model
        alexnet = models.alexnet(pretrained=True)
        # Select feature extraction part
        self.features = alexnet.features
        # Add layers
        self.layers = nn.Sequential(
          nn.Conv2d(256, 256, kernel_size=3, padding=0, stride=1),
          nn.ReLU(),
          nn.BatchNorm2d(256),
          nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(1024, 512),
            nn.Linear(512, 256),
            nn.Linear(256, num_classes)
        )

    
    def forward(self, x):
        # Go through the pre-trained layers
        x = self.features(x)
        # Go through added layers
        # HINT: check the output of the model without adding any layer to see the size of the feature maps from AlexNet
        x = self.layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layers(x)
        return x

# %%
# Create model
model = FineTunedAlexNet()

# %%
# Test model output
model.eval()
test_input = dog_train_dataset[0][0].unsqueeze(0)
print("Model output size:", model(test_input).size())
# Out:
# Model output size: torch.Size([1, 133])

# %%
# Move model to CUDA
model = model.to(dev)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.01)

# %% [markdown]
# Train the model again. You can re-use the same code written for from-scratch training.

# %%
# Initialize training history
# HINT: here you set up the lists for average loss/accuracy for all epochs
train_loss = []
train_acc = []
val_loss = []
val_acc = []
test_loss = []
test_acc = []
# Initialize best validation accuracy and test accuracy at best validation accuracy
best_val_accuracy = 0
test_accuracy_at_best_val = 0

# %%
for epoch in range(50):
    # Initialize variables for computing average loss/accuracy
    sum_loss = {"train": 0, "val": 0, "test": 0}
    sum_acc = {"train": 0, "val": 0, "test": 0}
    # Process each split
    for split in ["train", "val", "test"]:
        # Set network mode (train or eval)
        model.train();
        # Process all data in split
        for  i, (input, labels) in enumerate(loaders[split]):
            # Process each batch
            input = input.to(dev)
            labels = labels.to(dev)
            optimizer.zero_grad()
            pred = model(input)
            loss = F.cross_entropy(pred, labels)
            sum_loss[split] += loss.item()
            if split == "train":
              loss.backward()
              optimizer.step()
            _, pred_labels = pred.max(1)
            sum_acc[split] += (pred_labels == labels).sum().item()/input.size(0)
    # Compute average epoch loss/accuracy
    epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}
    epoch_acc = {split: sum_acc[split]/len(loaders[split]) for split in ["train", "val", "test"]}
    
    train_loss.append(epoch_loss["train"])
    train_acc.append(epoch_acc["train"])
    val_loss.append(epoch_loss["val"])
    val_acc.append(epoch_acc["val"])
    test_loss.append(epoch_loss["test"])
    test_acc.append(epoch_acc["test"])

    print(f"Epoch {epoch+1}:",
          f"TrL={epoch_loss['train']:.4f},",
          f"TrA={epoch_acc['train']:.4f},",
          f"VL={epoch_loss['val']:.4f},",
          f"VA={epoch_acc['val']:.4f},",
          f"TeL={epoch_loss['test']:.4f},",
          f"TeA={epoch_acc['test']:.4f},")
    # Check if we obtained the best validation accuracy
    if epoch_acc["val"] > best_val_accuracy:
        # Update best validation accuracy and test accuracy at best validation
        best_val_accuracy = epoch_acc["val"]
        test_accuracy_at_best_val = epoch_acc["test"]

# %%
# Print test accuracy at best validation accuracy
print(f"Final test accuracy {test_accuracy_at_best_val:.4f}")

# %%
# Plot loss history
plt.title("Loss")
plt.plot(train_loss, label="train")
plt.plot(val_loss, label="validation")
plt.plot(test_loss, label="test")
plt.legend()
plt.show()

# %%
# Plot accuracy history
plt.title("Accuracy")
plt.plot(train_acc, label="train")
plt.plot(val_acc, label="validation")
plt.plot(test_acc, label="test")
plt.legend()
plt.show()

# %%
# Get random sample from test set
idx = random.randint(0, len(dog_test_dataset)-1)
input, label = dog_test_dataset[idx]
# Normalize and show image
input_show = (input - input.min())/(input.max() - input.min())
plt.imshow(input_show.permute(1,2,0).numpy())
plt.axis('off')
# Predict class
model.eval()
with torch.no_grad():
    output = model(input.unsqueeze(0).to(dev))
_,pred = output.max(1)
pred = pred.item()
print(f"Predicted: {pred} (correct: {label})")
